# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('./experiment2/sim/chr19/chr19_correlation_coefficient_score.csv', )
df = df.set_index(df.columns[0])
df.dropna(inplace=True)
plt.figure(figsize=(24, 24))
sns.heatmap(df, annot=False, cmap='viridis', cbar=True)
plt.title('Sample Heatmap')
plt.show()

# %%
df = pd.read_csv('./experiment2/sim/chr20/chr20_correlation_coefficient_score.csv', )
df = df.set_index(df.columns[0])
df.dropna(inplace=True)
plt.figure(figsize=(24, 24))
sns.heatmap(df, annot=False, cmap='viridis', cbar=True)
plt.title('Sample Heatmap')
plt.show()

# %%
df = pd.read_csv('./experiment2/sim/chr22/chr22_correlation_coefficient_score.csv', )
df = df.set_index(df.columns[0])
df.dropna(inplace=True)
plt.figure(figsize=(24, 24))
sns.heatmap(df, annot=False, cmap='viridis', cbar=True)
plt.title('Sample Heatmap')
plt.show()

# %%
df = pd.read_csv('./experiment2/sim/chr17/chr17_correlation_coefficient_score.csv', )
df = df.set_index(df.columns[0])
df.dropna(inplace=True)
plt.figure(figsize=(24, 24))
sns.heatmap(df, annot=False, cmap='viridis', cbar=True)
plt.title('Sample Heatmap')
plt.show()

# %%
df = pd.read_csv('./experiment2/sim/chrX/chrX_correlation_coefficient_score.csv', )
df = df.set_index(df.columns[0])
df.dropna(inplace=True)
plt.figure(figsize=(24, 24))
sns.heatmap(df, annot=False, cmap='viridis', cbar=True)
plt.title('Sample Heatmap')
plt.show()
